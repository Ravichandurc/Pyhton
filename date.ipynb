# %% [markdown]
# import datetime as dt

# %%
import datetime as dt
import pandas as pd
#today date
date=dt.datetime.today()
td=dt.date.today()

# %%
print(date)
# Out:
# 2023-08-18 16:50:17.090600

# %%
print(date)
# Out:
# 10:37:49.482841

# %%
#getting month
td.month
# Out:
# 7

# %%
#getting the current timed
k=dt.datetime.now()
print(k)
# Out:
# datetime.datetime(2023, 8, 18, 16, 51, 36, 167205)

# %%
c=dt.date(2023,12,25)
c
# Out:
# datetime.date(2023, 12, 25)

# %%
print(c-td)
# Out:
# 173 days, 0:00:00

# %%
# parsing string to date
dome=dt.datetime.strptime('05-07-2023','%m-%d-%Y')
help(dt.datetime.strftime)
# Out:
# Help on method_descriptor:
#
# strftime(...)
#     format -> strftime() style string.

# %%
print(dome)
# Out:
# 2023-05-07 00:00:00

# %%
#finding date after 100 days from today

hdays=td+dt.timedelta(days=100)
print(hdays)
# Out:
# 2023-11-26

# %%
#help(dt.timedelta())

# %%
#check if the day is a weekday
#start monday =1,sun=7
dome.isoweekday()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 #check if the day is a weekday
#       2 #start monday =1,sun=7
# ----> 3 dome.isoweekday()
#
# NameError: name 'dome' is not defined

# %%
# start sunday 
dome.weekday()
# Out:
# 6

# %%
#strf time

k=dt.datetime.now().strftime('%d-%m-%Y')
#k=pd.to_datetime(k)
k
# Out:
# '18-08-2023'

# %%
#strf time

dt.datetime.now().strftime('%a')
# Out:
# 'Wed'

# %%
#strf time fro month

dt.datetime.now().strftime('%m')
# Out:
# '07'

# %%
#strf time fro month

dt.datetime.now().strftime('%B')
# Out:
# 'July'

# %%
df=pd.read_excel('sales.xlsx')
df.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0       1         3 2010-10-13            Low               6    261.5400
# 1      49       293 2012-10-01           High              49  10123.0200
# 2      50       293 2012-10-01           High              27    244.5700
# 3      80       483 2011-07-10           High              30   4965.7595
# 4      85       515 2010-08-28  Not Specified              19    394.2700
#
#    Discount       Ship Mode     Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air  -213.2500       38.94  ...  Muhammed MacIntyre
# 1      0.07  Delivery Truck   457.8100      208.16  ...        Barry French
# 2      0.01     Regular Air    46.7075        8.69  ...        Barry French
# 3      0.08     Regular Air  1198.9710      195.99  ...       Clay Rozendal
# 4      0.08     Regular Air    30.9400       21.78  ...      Carlos Soltero
#
#   Province   Region Customer Segment Product Category  \
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df=pd.read_excel('sales.xlsx',parse_dates=True)
df
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0          1         3 2010-10-13            Low               6    261.5400
# 1         49       293 2012-10-01           High              49  10123.0200
# 2         50       293 2012-10-01           High              27    244.5700
# 3         80       483 2011-07-10           High              30   4965.7595
# 4         85       515 2010-08-28  Not Specified              19    394.2700
# ...      ...       ...        ...            ...             ...         ...
# 8394    7765     55558 2010-08-09         Medium               8   1294.0400
# 8395    7766     55558 2010-08-09         Medium              23    392.5700
# 8396    7906     56550 2011-04-08  Not Specified              37    823.7800
# 8397    7907     56550 2011-04-08  Not Specified               8    469.8375
# 8398    7914     56581 2009-02-08           High              20   2026.0100
#
# ...

# %%
df=pd.read_excel('sales.xlsx',parse_dates=['date_col1','date_col2'])

# %%
df=pd.read_excel('sales.xlsx',parse_dates={'date_col1':'%y-%m-%d','date_col2':'%d/%m/%y'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 df=pd.read_excel('sales.xlsx',parse_dates={'date_col1':'%y-%m-%d','date_col2':'%d/%m/%y'})
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
df['new_column']=df['Ship Date'].dt.strftime('%A')
df
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0          1         3 2010-10-13            Low               6    261.5400
# 1         49       293 2012-10-01           High              49  10123.0200
# 2         50       293 2012-10-01           High              27    244.5700
# 3         80       483 2011-07-10           High              30   4965.7595
# 4         85       515 2010-08-28  Not Specified              19    394.2700
# ...      ...       ...        ...            ...             ...         ...
# 8394    7765     55558 2010-08-09         Medium               8   1294.0400
# 8395    7766     55558 2010-08-09         Medium              23    392.5700
# 8396    7906     56550 2011-04-08  Not Specified              37    823.7800
# 8397    7907     56550 2011-04-08  Not Specified               8    469.8375
# 8398    7914     56581 2009-02-08           High              20   2026.0100
#
# ...

# %%
df['new_column'].mode()
# Out:
# 0    Saturday
# Name: new_column, dtype: object

# %%
df['new_column'].value_counts()
# Out:
# Saturday     1259
# Sunday       1234
# Wednesday    1222
# Thursday     1207
# Friday       1165
# Monday       1158
# Tuesday      1154
# Name: new_column, dtype: int64
